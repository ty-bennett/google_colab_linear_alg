# %% [markdown]
# <a href="https://colab.research.google.com/github/ty-bennett/google_colab_linear_alg/blob/main/Math344L_Lab0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Math 344L")
# Out:
# Hello, Math 344L

# %%
import numpy as np

# %%
u = np.array([1,2,3])

# %%
u = np.array([[1],
             [2],
             [3]])

print(u)
# Out:
# [[1]
#  [2]
#  [3]]

# %%
A = np.array([[1,2],
             [3,4]])

# %%
3*A
# Out:
# array([[ 3,  6],
#        [ 9, 12]])

# %%
B = np.array([[3, 5],
             [7,8]])

# %%
A+B
# Out:
# array([[ 4,  7],
#        [10, 12]])

# %%
A.T
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
C = np.array([[1,2],[3,4]])

# %%
D = np.array([[5,6], [7,8]])

# %%
C@D
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
p_one_a = np.array([[1,0], [0,1]])

# %%
p_one_b = np.array([[2,3], [4,5]])

# %%
p_one_a@p_one_b
# Out:
# array([[2, 3],
#        [4, 5]])

# %%
p_two_a = np.array([[1,1,], [3,1]])

# %%
p_two_b = np.array ([2,3,4])

# %%
# p_two_a@p_two_b

# not possible because a and b are not the same shape
print(p_two_a.shape == p_two_b.shape)
# Out:
# False

# %%
A.shape
# Out:
# (2, 2)

# %%
w = np.array([1,2,3])
z = np.array([3,4,5])

# %%
np.dot(w,z)
# Out:
# np.int64(26)

# %%
import matplotlib.pyplot as plt

# %%
theta = np.linspace(0, 2*np.pi, 200)

X = np.array([
    np.cos(theta),
    np.sin(theta)
   ])

plt.plot(X[0], X[1])
plt.axis("equal")
plt.grid()
plt.show()
